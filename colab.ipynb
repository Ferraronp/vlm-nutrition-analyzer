# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))

# %%
# !pip install -q llama-cpp-python --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu124 > /dev/null

# %%
# !rm -rf vlm-nutrition-analyzer

# %%
# !git clone https://github.com/Ferraronp/vlm-nutrition-analyzer

# %%
# %cd vlm-nutrition-analyzer

# %%
# !pip install -q -r requirements.txt

# %%
# %%writefile .env
# GROQ_API_KEY=""

# %%
# !python app.py
